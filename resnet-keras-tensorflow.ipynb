# %%
import numpy as np
import pandas as pd
import keras

# %%
def _bn_relu(input):
    from keras.layers.normalization import BatchNormalization
    from keras.layers import Activation
    norm = BatchNormalization(axis = 3)(input)
    return Activation("relu")(norm)


def _bn_relu_conv(**conv_params):
    from keras.regularizers import l2
    from keras.layers import Conv2D
    filters = conv_params['filters']
    kernel_size = conv_params['kernel_size']
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1e-4))
    
    def f(input):
        activation = _bn_relu(input)
        return Conv2D(filters = filters, kernel_size = kernel_size,
                     strides = strides, padding = padding,
                     kernel_initializer = kernel_initializer,
                     kernel_regularizer = kernel_regularizer)(activation)
    
    return f


def _shortcut(input, residual):
    import keras.backend as K
    from keras.layers import Conv2D
    from keras.layers.merge import add
    from keras.regularizers import l2
    input_shape = K.int_shape(input)
    residual_shape = K.int_shape(residual)
    
    stride_width = int(round(input_shape[1] / residual_shape[1]))
    stride_height = int(round(input_shape[2] / residual_shape[2]))
    equal_channels = input_shape[3] == residual_shape[3]
    
    shortcut = input
    # 1 * 1 conv if shape is different. Else identity
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Conv2D(filters = residual_shape[3],
                         kernel_size = (1, 1),
                         strides = (stride_width, stride_height),
                         padding = "valid",
                         kernel_initializer = "he_normal",
                         kernel_regularizer = l2(1e-4))(input)
    return add([shortcut, residual])
    
    
def basic_block(filters, init_strides = (1, 1), is_first_block_of_first_layer = False):
    from keras.regularizers import l2
    from keras.layers import Conv2D
    def f(input):
        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv1 = Conv2D(filters = filters, kernel_size = (3, 3),
                          strides = init_strides,
                          padding = "same",
                          kernel_initializer = "he_normal",
                          kernel_regularizer = l2(1e-4))(input)
        else:
            conv1 = _bn_relu_conv(filters = filters, kernel_size = (3, 3),
                                 strides = init_strides)(input)

        residual = _bn_relu_conv(filters = filters, kernel_size = (3, 3))(conv1)
        return _shortcut(input, residual)
    
    return f


def _residual_block(filters, repetitions, is_first_layer = False):
    def f(input):
        for i in range(repetitions):
            init_strides = (1, 1)
            if i == 0 and not is_first_layer:
                init_strides = (2, 2)
            input = basic_block(filters, init_strides = init_strides, is_first_block_of_first_layer = (is_first_layer and i == 0))(input)
        return input
    
    return f
        
    
def _conv_bn_relu(**conv_params):
    from keras.layers import Conv2D
    from keras.regularizers import l2
    filters = conv_params['filters']
    kernel_size = conv_params['kernel_size']
    strides = conv_params.setdefault('strides', (1, 1))
    kernel_initializer = conv_params.setdefault('kernel_initializer', 'he_normal')
    padding = conv_params.setdefault('padding', 'same')
    kernel_regularizer = conv_params.setdefault('kernel_regularizer', l2(1e-4))
    
    def f(input):
        conv = Conv2D(filters = filters, kernel_size = kernel_size,
                     strides = strides, padding = padding,
                     kernel_initializer = kernel_initializer,
                     kernel_regularizer = kernel_regularizer)(input)
        return _bn_relu(conv)
    return f


def build_model(input_shape, num_outputs):
    from keras.layers import Input, MaxPooling2D, AveragePooling2D, Flatten, Dense
    from keras.models import Model
    import keras.backend as K
    input = Input(shape = input_shape)
    conv1 = _conv_bn_relu(filters = 64, kernel_size = (5, 5), strides = (2, 2))(input)
    pool1 = MaxPooling2D(pool_size = (3, 3), strides = (2, 2), padding = "same")(conv1)
    
    block = pool1
    filters = 64
    for i, r in enumerate([2, 2, 2, 2]):
        block = _residual_block(filters, repetitions = r, is_first_layer = (i == 0))(block)
        filters *= 2
        
    block = _bn_relu(block)
    
    # Classifier block
    block_shape = K.int_shape(block)
    pool2 = AveragePooling2D(pool_size = (block_shape[1], block_shape[2]), strides = (1, 1))(block)
    flatten1 = Flatten()(pool2)
    dense = Dense(num_outputs, kernel_initializer = "he_normal", activation = "softmax")(flatten1)
    model = Model(inputs = input, outputs = dense)
    return model

# %%
model = build_model((30, 30, 3), (5))

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 30, 30, 3)    0
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 15, 15, 64)   4864        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 15, 15, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 15, 15, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)     0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 64)     36928       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 64)     256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 8, 8, 64)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 64)     36928       activation_25[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 64)     0           max_pooling2d_3[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 64)     256         add_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 8, 8, 64)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 64)     36928       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 64)     256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 64)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     36928       activation_27[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 64)     0           add_11[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 64)     256         add_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 64)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 4, 4, 128)    73856       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 128)    512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 128)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 4, 4, 128)    8320        add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 4, 4, 128)    147584      activation_29[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 128)    0           conv2d_35[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 128)    512         add_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 128)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 128)    147584      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 128)    512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 128)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 128)    147584      activation_31[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 128)    0           add_13[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 128)    512         add_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 128)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 2, 2, 256)    295168      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 2, 2, 256)    1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 2, 2, 256)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 2, 2, 256)    33024       add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 2, 2, 256)    590080      activation_33[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 256)    0           conv2d_40[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 2, 2, 256)    1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 2, 2, 256)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 2, 2, 256)    590080      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 2, 2, 256)    1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 2, 2, 256)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 2, 2, 256)    590080      activation_35[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 2, 2, 256)    0           add_15[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 2, 2, 256)    1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 2, 2, 256)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 1, 1, 512)    1180160     activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 1, 1, 512)    2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 1, 1, 512)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 1, 1, 512)    131584      add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 1, 1, 512)    2359808     activation_37[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 1, 1, 512)    0           conv2d_45[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 1, 1, 512)    2048        add_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 1, 1, 512)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 1, 1, 512)    2359808     activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 1, 1, 512)    2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 1, 1, 512)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 1, 1, 512)    2359808     activation_39[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 1, 1, 512)    0           add_17[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 1, 1, 512)    2048        add_18[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 1, 1, 512)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 512)    0           activation_40[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            2565        flatten_2[0][0]
# ==================================================================================================
# Total params: 11,185,285
# Trainable params: 11,177,477
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model

# %%
plot_model(model, to_file = 'model_auth.png', show_shapes= True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-30f0a84d090e> in <module>
# ----> 1 plot_model(model, to_file = 'model_auth.png', show_shapes= True)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     238     """
#     239     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir,
# --> 240                        expand_nested, dpi)
#     241     _, extension = os.path.splitext(to_file)
#     242     if not extension:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#      77     from ..models import Sequential
#      78
# ---> 79     _check_pydot()
#      80     if subgraph:
#      81         dot = pydot.Cluster(style='dashed', graph_name=model.name)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/keras/utils/vis_utils.py in _check_pydot()
#      20     if pydot is None:
#      21         raise ImportError(
# ---> 22             'Failed to import `pydot`. '
#      23             'Please install `pydot`. '
#      24             'For example with `pip install pydot`.')
#
# ImportError: Failed to import `pydot`. Please install `pydot`. For example with `pip install pydot`.
